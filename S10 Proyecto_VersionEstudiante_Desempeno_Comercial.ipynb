# %% [markdown]
# # Hola! 😀
#
# Soy **Jaime Paz** y mis amigos me suelen llamar James! - *"Tranquilo, no juego en el Real Madrid"* ⚽😅. Sí, como el futbolista James Rodríguez, pero en versión científico de datos... y mejor no me digas como a él. 😉
#
# Como tu revisor en TripleTen, estoy aquí para ayudarte a pulir tu código y tu forma de trabajar con datos. Si algo necesita un ajuste, no te preocupes: la idea es que cada comentario te acerque más a cómo se trabaja en un entorno profesional y que tu proyecto brille con todo su potencial.
#
# Cada vez que encuentre un detalle importante en tu proyecto, te lo señalaré para que puedas corregirlo y seguir creciendo. Si en algún punto no logras resolver algo, también estoy para guiarte en próximos intentos de revisión. 🔁
#
# Es muy importante que, cuando veas mis comentarios, **no los muevas, no los modifiques y no los borres**. Así mantenemos un historial claro de lo que ya revisamos y de tus avances. ✅
#
# ---
#
# ### Formato de Comentarios
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> ✅ - ¡Excelente trabajo! Esta parte está bien implementada y contribuye de forma positiva al análisis o al proyecto.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Atención</b> ⚠️ - Esta parte funciona, pero todavía se puede reforzar para que quede más clara, más completa o más sólida.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>A resolver</b> ❗ - Aquí hay un punto importante por corregir porque afecta la validez del análisis, la implementación o la entrega.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
#
#
# <b>Éxito</b> ✅ - ¡Excelente trabajo Ana! Tu proyecto es excepcional y has logrado cubrir los objetivos del mismo. Abajo he dejado mis comentarios y unas pequeñas recomendaciones para que tomes en cuenta en un futuro y te hagan ¡un máster en Data!
#
# ¡Felicidades!
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>A resolver</b> ❗ - HOLA ANA!!!! PARA TU SIGUIENTE ENTREGA TE PIDO SI PUEDES AGREGAR EL LINK DE TABLEAU (PUBLICO) PARA QUE PUEDA APRECIAR TU DASHBOARD. LAMENTABLEMENTE EL FORMATO QUE HAS SUBIDO, NO ES POSIBLE VISUALIZAR TU ENTREGA.
#
# **PERDONA LOS INCONVENIENTES, ESPERO EL LINK EN TU PROXIMA ENTREGA**

# %% [markdown]
# # 📊 Proyecto: Dashboard de desempeño comercial 2024–2025
# Empresa: **Andes Retail Group**
#
# Este notebook servirá como guía estructurada para el desarrollo del proyecto.
# Sigue cada paso y espera feedback del evaluador.

# %% [markdown]
# ## 🔹 Paso 1: Conexión y Exploración
#
# - Importa el archivo excel en Power BI Desktop o en Tableau.
# - Revisa tipos de datos.
# - Identifica columnas clave.
# - Explora estructura general del dataset.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# ## 🔹 Paso 2: Preparación de los datos
#
# - Cambia el formato de `Fecha_pedido` a español (Latinoamérica).
# - Corrige los **tipos de datos** de columnas numéricas.
# - Crea una columna condicional `Nivel_Venta` basada en `Ingresos`. Reglas:
#   - Si `Ingresos` es mayor o igual a 1000 → "Venta Alta"
#   - De lo contrario → "Venta Baja"
# - Activa **Vista Perfil de Columna** para validar calidad.
# - Deja el dataset listo para análisis.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# ## 🔹 Paso 3: Diseño y planificación del Dashboard (antes y durante la construcción)
#
# - Define qué pregunta responde cada vista (Overview y Detalle).
# - Especifica qué KPIs incluirás y por qué.
# - Explica qué gráfico usarás para cada pregunta y justifica la elección.
# - Describe la jerarquía visual (qué verá primero el usuario).
#     - Indica cómo distribuirás los elementos en la página.
# - Especifica qué filtros o segmentadores usaras.

# %% [markdown]
# ### Diseño y planificación
# ✏️ Describe aquí brevemente tu planificación antes de construir el dashboard.
# - Haz una planeación inicial, después, conforme vayas creando el dashboard, puedes regresar y modificar estas secciones acorde a lo que vayas encontrando.
#
# El dashboard se diseñará para ofrecer a la dirección ejecutiva una visión clara, rápida y accionable del desempeño comercial entre 2024 y 2025.
#
# Se dividirá en dos niveles:
#
# Vista General/Overview: para entender rápidamente el estado del negocio.
# Vista Detalle: para analizar las causas detrás del comportamiento observado.
#
# El enfoque será responder preguntas estratégicas relacionadas con ingresos, rentabilidad, clientes, productos, geografía y temporalidad, facilitando la toma de decisiones.
#
# #### Vista Overview - ¿Cómo ha evolucionado el ingreso total entre 2024 y 2025?
# **Especifica qué KPIs incluirás y por qué: (3-4 KPIs)**
# - Ingresos: Permite evaluar el volumen total de ventas y su evolución.
# - Unidades Vendidas: Complementa el análisis mostrando el volumen comercial.
# - Ganancias (Ingresos - Costo): Ayuda a entender si el negocio está generando valor real.
#
# **Visualizaciones**
# Explica qué gráfico usarás para cada pregunta y justifica la elección.
#
# Gráfico de tiempo:
# Gráfico de líneas – Ingresos vs Fecha_Pedido (por mes, separado por año) 👉 Permite analizar la evolución del ingreso y comparar tendencias entre 2024 y 2025.
#
# Gráfico comparación geográfica:
# Gráfico de barras o mapa – Ingresos por País o Región
# 👉 Permite identificar diferencias de desempeño entre mercados.
#
# Gráfico comparación clientes/productos:
# Gráfico de barras horizontales – Ingresos por Segmento_Cliente
# 👉 Permite identificar qué segmentos aportan mayor valor.
#
# Gráfico categorías de producto:
# Gráfico de barras – Ingresos por Categoría_Producto
# 👉 Permite identificar qué productos impulsan el negocio
#
# **Descripción de la jerarquía visual:**
# - Título: Desempeño Comercial 2024–2025
# - Parte superior: KPIs principales
# - Centro: Tendencia de ingresos (gráfico principal)
# - Parte inferior: Segmentos de clientes y categorías de producto
# - Esquina inferir derecha: Botón para navegar al Dashboard "Detalles"
#
# Filtro(s)
# - Año
# - Mes
#
# #### Vista detalle - ¿Por qué se han caido/subido/mantenido los ingresos?
# Explica qué gráfico usarás para cada pregunta y justifica la elección.
# - Gráfico comparación estacional contra ingresos: Gráfico de barras `Ingresos` vs 'Estación'
# 👉 Permite identificar patrones estacionales y su impacto en ventas.
#
# - Gráfico comparación clientes contra rentabilidad:
# - Gráfico de barras -'Ganancias' por 'Segmento_cliente'
# 👉 Permite identificar qué segmentos son más rentables o menos eficientes.
#
# Gráfico comparación productos contra desempeño:
# Gráfico de barras – Ingresos y Costo por Categoría_Producto
# 👉 Permite analizar qué productos generan mayor valor o menor margen.
#
# Gráfico comparación geográfica detallada:
# Gráfico de barras – Ingresos y/o Utilidad por Región
# 👉 Permite detectar regiones con bajo o alto desempeño.
#
# - Tabla mostrando 4-6 columnas:
#   - Conteo `ID_Pedido`
#   - Conteo único `ID_Cliente`
#   - Ingresos
#   - Costo
#   - Unidades_Vendidas
#   - Categoría_Producto o Segmento_Cliente
#   - Ganancias
# 👉 Permite hacer análisis más granular y validar hallazgos.
#
# Filtros (mínimo 2)
# - `Fecha_pedido`
# -  'País'
# -  'Categoría-Producto'
# -  'Segmento_Cliente'

# %% [markdown]
# ## 🔹 Paso 4: Crear visualizaciones efectivas
#
# - Construir Vista 1 (Overview Ejecutivo).
# - Construir Vista 2 (Análisis Detallado).
# - Asegurar claridad y coherencia visual.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios en caso de ser necesario._

# %% [markdown]
# ## 🔹 Paso 5: Narrativa con Modelo SCQA + mensaje asincrónico
#
# - Escribe la narrativa que
#   - refleja lo que se observa en la **Vista General (Overview)**.
#   - explica los hallazgos en la **Vista Detalle**.
# - Utiliza el modelo **SCQA (Situación, Complicación, Pregunta, Respuesta)**.
# - Mantén la narrativa clara, ejecutiva y breve.
# - Redacta un mensaje ejecutivo tipo Slack resumiendo el insight principal.

# %% [markdown]
# ### Narrativa del Dashboard (Modelo SCQA)
# Se describe de forma estructurada la historia completa del dashboard usando SCQA, incluyendo contexto, problemas detectados, preguntas de negocio y recomendaciones basadas en datos.

# %% [markdown]
# #### 🖥️ Vista General (Overview)
#
# **S (Situación):**
# Cuando observamos el desempeño comercial de 2024 a 2025, vemos un negocio que sí está generando ingresos, pero no de forma uniforme y presenta patrones similares en ambos años en altas y bajas en ingresos.
# Hay momentos del año donde el desempeño mejora y otros donde pierde fuerza, y lo mismo ocurre al verlo con clientes, productos y paises.
#
# **C (Complicación):**
# El reto es que, el crecimiento no es uniforme, existen variaciones relevantes entre periodos y no es evidente qué está realmente impulsando el negocio.
#
# No todos los clientes aportan el mismo valor, no todos los productos son igual de rentables y no todos los mercados se comportan igual.
#
# Esto hace que, sin una vista clara, sea difícil saber dónde enfocar los esfuerzos comerciales.
#
# **Q (Pregunta):**
# ¿Cuáles son los principales factores/motivos del ingreso y la rentabilidad, y en qué áreas existen oportunidades para mejorar el desempeño comercial?
#
# **A (Respuesta):**
# El crecimiento no es uniforme: ingresos y rentabilidad varían por temporada, cliente y producto.
# La oportunidad está en enfocar la estrategia comercial en los segmentos y categorías que realmente generan valor y ajustar lo que no está siendo tan rentable.
#
# ---
#
# #### 🔎 Vista Detalle
#
# **S (Situación):**
# Al observar al detalle, podemos ver cómo se distribuyen los ingresos entre estaciones, categorías de producto y segmentos de cliente. Aquí ya no solo vemos el resultado general, sino cómo se construye el negocio desde dentro, entrelazando las fuerzas y factores que intervienen.
#
# **C (Complicación):**
# Lo interesante es que el desempeño comercial no es homogéneo: hay combinaciones específicas de temporada, producto y tipo de cliente que concentran la mayor parte del ingreso, mientras otras aportan mucho menos. Esto muestra que no todo lo que se vende contribuye igual al negocio.
#
# **Q (Pregunta):**
# ¿Qué combinaciones están generando valor real? ¿Y cuáles podrían estar representando una oportunidad de mejora?
#
# **A (Respuesta):**
# El análisis detallado permite identificar que ciertos segmentos de clientes y categorías de producto tienen un peso mucho mayor en el ingreso, especialmente en temporadas específicas.
#
# Esto nos muestra que: El desempeño del negocio depende de combinaciones muy puntuales. Hay áreas donde el ingreso está concentrado. Y otras donde existe potencial de optimización Con esta claridad, es posible enfocar mejor las estrategias comerciales y tomar decisiones más precisas.

# %% [markdown]
# ### Mensaje asincrónico para Slack (Modelo SCQA)
#
# Resume los insights más importantes en un mensaje breve.
# - Comunica impacto en negocio y acciones recomendadas, como si lo enviaras a stakeholders por Slack.
# - Escribe un mensaje directo y conciso.

# %% [markdown]
# **📊 Actualización desempeño comercial**
#
# Equipo, el análisis muestra que el desempeño comercial no es uniforme: los ingresos se concentran en ciertas temporadas (Verano princialmente), segmentos de clientes (Premium/2° Estandar) y categorías de producto (1°Deportes/2°Hogar-Electroncia.
#
# Esto indica que no todas las combinaciones (estación/cliente/productos) están generando el mismo valor, lo que puede estar limitando la rentabilidad general del negocio, así como el impacto en el comportamiento por país.
#
# La pregunta clave es dónde enfocar los esfuerzos para maximizar el impacto.
#
# Recomendación: priorizar las combinaciones de mayor desempeño (temporada + cliente + producto) y revisar aquellas con bajo aporte para optimizar la estrategia comercial y mejorar la rentabilidad.

# %% [markdown]
# ### 📝 Feedback del evaluador
#
# _El evaluador escribirá aquí sus comentarios._

# %% [markdown]
# ## 🚀 Entrega Final
#
# Comparte el acceso a tu proyecto final para revisión.
#
# Incluye **una** de las siguientes opciones, según la herramienta que hayas utilizado:
# - 🔗 Link público del dashboard publicado (Power BI Service o Tableau Public), o
# - 🔗 Link público de Google Drive/OneDrive con el archivo `.pbix`, o
# - ✅ Confirmación de que el archivo `.pbix` fue subido como indica el screencast.
#
# ### 📎 Enlace del proyecto:

# %% [markdown]
# ✏️ (Pega aquí tu link o escribe "Subi mi proyecto a la plataforma")

# %%
https://public.tableau.com/app/profile/ana.barriga/viz/Proyecto_9_AnaDeliaBarriga_v7/General?publish=yes

# %%
Hola Jaime, buena tarde!! te comparto el enlace de mi Dashboard en tableau public, espero esta vez sea visible. Quedo atenta. Saludos!

# %% [markdown]
# ## Tabla de evaluación
#
# | Parte | Criterio | Estado | Puntaje obtenido | Puntaje máximo | Comentario breve |
# |---|---|---|---:|---:|---|
# | Parte 1 | Importación del Excel | ✅ Logrado | 5 | 5 | El dashboard publicado y la captura evidencian carga de datos |
# | Parte 2 | Tipos de datos correctos | ✅ Logrado  | 5 | 5 | La línea temporal y tus agregados numéricos sugieren tipos bien configurados |
# | Parte 2 | Columna Ganancia | ✅ Logrado | 5 | 5 | Se observa el KPI de Ganancias y en la planificación se menciona la lógica `Ingresos - Costo` |
# | Parte 2 | Columna condicional `Nivel de Venta` | ✅ Logrado | 5 | 5 | Columna relacionada a un `Nivel de Venta` presente |
# | Parte 3 | Definición de vistas | ✅ Logrado | 4 | 4 | El notebook distingue con claridad qué responde la vista `Overview` y qué se analizaría en `Detalle`. |
# | Parte 3 | Selección de KPIs | ✅ Logrado | 4 | 4 | Se justifican KPIs ejecutivos coherentes como Ingresos, Unidades Vendidas y Ganancias. |
# | Parte 3 | Elección de gráficos | ✅ Logrado | 4 | 4 | La elección de línea para tendencia y barras para comparaciones está bien argumentada y alineada con la rúbrica. |
# | Parte 3 | Jerarquía visual | ✅ Logrado | 3 | 3 | La distribución propuesta y la captura muestran una lectura lógica: KPIs arriba, tendencia al centro y comparativos abajo. |
# | Parte 4.1 | KPIs principales | ✅ Logrado | 6 | 6 | La vista general muestra 3 KPIs claros e incluye `Ingresos`, `Unidades Vendidas` y `Ganancias`. |
# | Parte 4.1 | Gráfico de tendencia temporal | ✅ Logrado | 5 | 5 | Se observa un gráfico de líneas con `Fecha Pedido` e `Ingresos`, útil para seguir la evolución mensual. |
# | Parte 4.1 | Comparación geográfica | ✅ Logrado | 4 | 4 | La vista incluye barras por país para comparar el ingreso por mercado. |
# | Parte 4.1 | Comparación clientes/productos | ✅ Logrado | 4 | 4 | Se muestra comparación por segmento de cliente con barras, cumpliendo el criterio solicitado. |
# | Parte 4.1 | Gráfico opcional | ✅ Logrado | 2 | 2 | Además de los gráficos mínimos, se incorpora una comparación adicional por categoría de producto que aporta contexto. |
# | Parte 4.1 | Claridad ejecutiva | ✅ Logrado | 4 | 4 | La vista es rápida de interpretar: buen título, KPIs visibles y una pregunta central que orienta la lectura. |
# | Parte 4.1 | Segmentador opcional | ✅ Logrado | 2 | 2 | Se observan dos filtros visibles, año y mes, sin sobrecargar la composición. |
# | Parte 4.2 | Estación vs Ingresos | 🟡 Recomendación | 2 | 5 | Para este segmento, necesitamos una vista especial en el dashboard |
# | Parte 4.2 | Comparaciones adicionales | 🟡 Recomendación | 2 | 5 | Propones comparaciones adicionales en el notebook, pero no hay evidencia visual suficiente para confirmar cuántas fueron implementadas. |
# | Parte 4.2 | Tabla de detalle | 🟡 Recomendación | 2 | 5 | Se describe una tabla útil con varias columnas, aunque no se pudo verificar su presencia o bien una estructura final. |
# | Parte 4.2 | Segmentación | 🟡 Recomendación | 2 | 5 | El notebook plantea varios filtros para detalle, pero la evidencia visual disponible no permite confirmar al menos dos segmentadores en esa vista. |
# | Parte 5.1 | Situation | 🟡 Recomendación | 2 | 3 | La vista general transmite el estado del negocio con KPIs y tendencia, aunque la narrativa visible podría apoyarse más en datos concretos. |
# | Parte 5.1 | Complication | 🟡 Recomendación | 1 | 2 | La complicación se entiende mejor en tu notebook que en la evidencia visual del dashboard, por eso la validación queda parcial. |
# | Parte 5.1 | Question | ✅ Logrado | 2 | 2 | La pregunta central del negocio sí aparece claramente en la vista general. |
# | Parte 5.1 | Answer | 🟡 Recomendación | 1 | 3 | Hay recomendaciones en el notebook, pero no pude verificar que la respuesta ejecutiva esté integrada de forma visible en el dashboard publicado. |
# | Parte 5.2 | Situation | 🟡 Recomendación | 2 | 3 | El mensaje asincrónico resume bien el comportamiento general, aunque podría fortalecerse con una o dos cifras concretas. |
# | Parte 5.2 | Complication | ✅ Logrado | 2 | 2 | Se explica con claridad que el desempeño no es uniforme entre temporadas, segmentos y categorías. |
# | Parte 5.2 | Question | ✅ Logrado | 2 | 2 | La pregunta estratégica sobre dónde enfocar esfuerzos comerciales es clara y coherente. |
# | Parte 5.2 | Answer | 🟡 Recomendación | 2 | 3 | La recomendación es accionable, pero sería más sólida si priorizara acciones con apoyo cuantitativo más explícito. |
#
# ## Subtotal Parte 1
# **5 / 5**
#
# ## Subtotal Parte 2
# **15 / 15**
#
# ## Subtotal Parte 3
# **15 / 15**
#
# ## Subtotal Parte 4.1
# **25 / 25**
#
#
# ## Subtotal Parte 4.2
# **8 / 20**
#
# ## Subtotal Parte 5.1
# **6 / 10**
#
# ## Subtotal Parte 5.2
# **8 / 10**
#
# ## Total final
# **82 / 100**
#
# ## Comentario final del revisor
#
# Buen trabajo Ana! en general, presentass una propuesta con buena intención ejecutiva y una **vista general bastante sólida**, especialmente por la claridad de los KPIs, la tendencia temporal y las comparaciones por mercado, cliente y categoría. También destacas positivamente que en el notebook sí hiciste el ejercicio de planear las vistas, justificar gráficos y redactar una narrativa SQCA coherente.
#
# Tus puntos más fuertes están en la **planificación del dashboard** y en la **ejecución del Overview**, que se entiende rápido y responde bien a preguntas de negocio. Además, el mensaje asincrónico comunica una dirección estratégica clara y mantiene un tono ejecutivo adecuado.
#
# Para llevar este proyecto a un nivel más fuerte, te recomiendo enfocarte en tres frentes: documentar mejor la **preparación técnica de los datos** en el notebook y mostrar evidencia verificable de la **vista de detalle** (separada). También te ayudaría reforzar la narrativa con cifras puntuales para que las conclusiones tengan todavía más peso analítico.
#
# Vas por un muy buen camino, Ana! Ya tienes una base visual clara y una intención analítica correcta. Si refuerzas la parte técnica y haces más verificable la segunda vista, tu entrega puede subir con bastante facilidad en una próxima iteración. ¡Sigue así!
